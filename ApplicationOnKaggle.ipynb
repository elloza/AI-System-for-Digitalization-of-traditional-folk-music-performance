# %% [markdown]
# # AI tool for digitalization of traditional folk music

# %% [markdown]
# [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://www.kaggle.com/code/elloza/ai-tool-for-digitalization-of-traditional-folk-mus)

# %% [markdown]
# # Install libraries (This could take a while ⌛⌛10-15 minutes⌛⌛)

# %% [markdown]
# ## Install libraries for the different components of the project

# %%
from IPython.display import display, HTML, clear_output

def clear(message):
    clear_output(wait=True)
    display(HTML(f'<span style="color: green;">{message}</span>'))

clear("Completed")
# Out:
# <span style="color: green;">Completed</span>

# %% [markdown]
# ### App libraries

# %%
### Libraries of the app
# !pip install streamlit -q
# !pip install streamlit_player
# !pip install streamlit-pdf-viewer
# !pip install midi-player
clear("Completed")
# Out:
# <span style="color: green;">Completed</span>

# %% [markdown]
# ### Download videos from YouTube/Vimeo

# %%
# !apt-get install -y software-properties-common && apt-get update && apt-get install -y ffmpeg
# !python -m pip install --no-cache-dir git+https://github.com/yt-dlp/yt-dlp.git@2023.07.06
# !rm /usr/local/bin/youtube-dl
# !ln -s $(which yt-dlp) /usr/local/bin/youtube-dl
clear("Completed")
# Out:
# <span style="color: green;">Completed</span>

# %% [markdown]
# ### Split audio from the videos in two (Vocals and Instrumental) Deezer Spleeter

# %%
# !pip install spleeter
clear("Completed")
# Out:
# <span style="color: green;">Completed</span>

# %% [markdown]
# ### Extract the lyrics from the audio (vocals) Fast whisper

# %%
# !pip install faster-whisper
clear("Completed")

# %% [markdown]
# ### Extract the music xml, midi and sheet music from the instrumental audio - Sheetsage project

# %%
# Install Jukebox
# !python -m pip install --no-cache-dir torch==1.12.0+cu113 --extra-index-url https://download.pytorch.org/whl/cu113
# !python -m pip install --no-cache-dir numba==0.58.1
# !python -m pip install --no-cache-dir resampy==0.2.2
# !python -m pip install --no-cache-dir librosa==0.10.1

# !apt-get install -y libopenmpi-dev
# !apt-get install -y openssh-server
# !python -m pip install --no-cache-dir mpi4py==3.1.5
# !apt-get install -y git
# !python -m pip install --no-cache-dir git+https://github.com/XaryLee/jukebox.git@ddc3577b50a4085be0ef65e17e9863686dadef40
# !python -m pip install --no-cache-dir requests==2.26.0

# Install pretty_midi
# !apt-get install -y fluidsynth
# !python -m pip install --no-cache-dir pyFluidSynth==1.3.0
# !python -m pip install --no-cache-dir pretty_midi==0.2.9

# Install madmom
# !python -m pip install --no-cache-dir Cython==0.29.24
# !python -m pip install --no-cache-dir git+https://github.com/XaryLee/madmom.git

# Install lilypond
# !apt-get install -y lilypond

# Install mir_eval
# !python -m pip install --no-cache-dir mir_eval==0.7

# Install validators
# !python -m pip install --no-cache-dir validators==0.20.0

# Install Flask
# !python -m pip install --no-cache-dir requests==2.26.0
# !python -m pip install --no-cache-dir Flask==2.0.3
# !python -m pip install --no-cache-dir Flask-Cors==3.0.10

clear("Completed")

# %%
# !pip install protobuf==3.20.3
clear("Completed")

# %%
# !apt-get install -y fluidsynth  # Instalar FluidSynth
# !pip install midi2audio        # Instalar midi2audio para usar FluidSynth en Python
clear("Completed")
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fluidsynth is already the newest version (2.1.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# ...

# %%
# !git clone https://github.com/elloza/sheetsage.git
# !pwd
# %cd /kaggle/working/sheetsage
clear("Completed")
# !pwd
# Out:
# Cloning into 'sheetsage'...
# remote: Enumerating objects: 364, done.
# remote: Counting objects: 100% (364/364), done.
# remote: Compressing objects: 100% (216/216), done.
# remote: Total 364 (delta 186), reused 276 (delta 133), pack-reused 0
# Receiving objects: 100% (364/364), 2.91 MiB | 15.85 MiB/s, done.
# Resolving deltas: 100% (186/186), done.
# /kaggle/working
# /kaggle/working/sheetsage
# /kaggle/working/sheetsage

# %%
# !python -m pip install --no-cache-dir -e .
clear("Completed")
# Out:
# Obtaining file:///kaggle/working/sheetsage
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for sheetsage (pyproject.toml) ... done
#   Created wheel for sheetsage: filename=sheetsage-0.0.0-0.editable-py3-none-any.whl size=3467 sha256=cad86d653a01ee97746e5e4c8c884c62b4bbfb023f92d1da582a5a1a678cf4a8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_4q9awr_/wheels/67/ab/3a/75305077d5811dd15ae92bbb8bd2689ed6ace047cc90f28cd3
# Successfully built sheetsage
# ...

# %%
import os
os.environ['SHEETSAGE_CACHE_DIR'] = '/root/.cache'
# !echo $SHEETSAGE_CACHE_DIR
clear("Completed")
# Out:
# <span style="color: green;">Completed</span>

# %%
# Download assets using aria 2 
# !apt -y install -qq aria2
clear("Completed")
# Out:
# <span style="color: green;">Completed</span>

# %%
# !mkdir -p /root/.cache/sheetsage/v0.2/0919_02_e0908_oafmelspecnorm
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M -d /root/.cache/sheetsage/v0.2/0919_02_e0908_oafmelspecnorm -o 5b739ce5efa2b6d4d70c5f1feac802684f0ee6f4.cfg.json https://sheetsage.s3.amazonaws.com/sheetsage/v0.2/0919_02_e0908_oafmelspecnorm/5b739ce5efa2b6d4d70c5f1feac802684f0ee6f4.cfg.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M -d /root/.cache/sheetsage/v0.2/0919_02_e0908_oafmelspecnorm -o model.pt https://sheetsage.s3.amazonaws.com/sheetsage/v0.2/0919_02_e0908_oafmelspecnorm/model.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M -d /root/.cache/sheetsage/v0.2/0919_02_e0908_oafmelspecnorm -o step.pkl https://sheetsage.s3.amazonaws.com/sheetsage/v0.2/0919_02_e0908_oafmelspecnorm/step.pkl

# !mkdir -p /root/.cache/sheetsage/v0.2/0919_00_e0830_oafmelspecnorm
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M -d /root/.cache/sheetsage/v0.2/0919_00_e0830_oafmelspecnorm -o 7d82e6839e582936ea428a823a0d868075a52dc5.cfg.json https://sheetsage.s3.amazonaws.com/sheetsage/v0.2/0919_00_e0830_oafmelspecnorm/7d82e6839e582936ea428a823a0d868075a52dc5.cfg.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M -d /root/.cache/sheetsage/v0.2/0919_00_e0830_oafmelspecnorm -o model.pt https://sheetsage.s3.amazonaws.com/sheetsage/v0.2/0919_00_e0830_oafmelspecnorm/model.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M -d /root/.cache/sheetsage/v0.2/0919_00_e0830_oafmelspecnorm -o step.pkl https://sheetsage.s3.amazonaws.com/sheetsage/v0.2/0919_00_e0830_oafmelspecnorm/step.pkl

# !mkdir -p /root/.cache/sheetsage/v0.2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M -d /root/.cache/sheetsage/v0.2 -o oafmelspec_moments.npy https://sheetsage.s3.amazonaws.com/sheetsage/v0.2/oafmelspec_moments.npy

# !mkdir -p /root/.cache/jukebox/models/5b
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M -d /root/.cache/jukebox/models/5b -o prior_level_2.pth.tar https://openaipublic.azureedge.net/jukebox/models/5b/prior_level_2.pth.tar
clear("Completed")
# Out:
# <span style="color: green;">Completed</span>

# %%
# Double check
# !python -m sheetsage.assets SHEETSAGE_V02_HANDCRAFTED
# !python -m sheetsage.assets JUKEBOX
# !python -m sheetsage.assets SHEETSAGE_V02_JUKEBOX
clear("Completed")
# Out:
# <span style="color: green;">Completed</span>

# %% [markdown]
# # Download de repository with the app

# %%
# %cd /kaggle/working
# !rm -rf AI-System-for-Digitalization-of-traditional-folk-music-performance
# !git clone https://github.com/elloza/AI-System-for-Digitalization-of-traditional-folk-music-performance.git
# %cd /kaggle/working/AI-System-for-Digitalization-of-traditional-folk-music-performance
# Out:
# /kaggle/working
# Cloning into 'AI-System-for-Digitalization-of-traditional-folk-music-performance'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 84 (delta 34), reused 35 (delta 15), pack-reused 25
# Unpacking objects: 100% (84/84), 127.78 MiB | 11.22 MiB/s, done.
# /kaggle/working/AI-System-for-Digitalization-of-traditional-folk-music-performance

# %%
# !ls -l
# Out:
# total 36
# -rw-r--r-- 1 root root  1085 Feb 21 13:32 LICENSE
# -rw-r--r-- 1 root root  3071 Feb 21 13:32 README.md
# -rw-r--r-- 1 root root  7382 Feb 21 13:32 app.py
# drwxr-xr-x 3 root root  4096 Feb 21 13:32 pretrained_models
# -rw-r--r-- 1 root root   833 Feb 21 13:32 requirements.txt
# -rw-r--r-- 1 root root 10224 Feb 21 13:32 utils.py

# %% [markdown]
# # YOUR IP (WHICH IS YOUR PASSWORD FOR THE LINKS BELOW)

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.28.59.197

# %%
# %cd /kaggle/working/AI-System-for-Digitalization-of-traditional-folk-music-performance
# !npx -y clear-npx-cache
# !streamlit run app.py --server.port 8502 & npx -y localtunnel --port 8502
# Out:
# /kaggle/working/AI-System-for-Digitalization-of-traditional-folk-music-performance
# m##################] - reify:cli-progress: timing reifyNode:node_modules/emoji-0m Starting cleaning ...
#
# 7 ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 0% | ETA: 0s | 0/2 ████████████████████████████████████████ 100% | ETA: 0s | 2/28
#
#  Cache cleared successfully! Thanks for using our lib.
# [#########.........] / idealTree:75ac80b86e83d4a2: timing idealTree:#root Compl
# ...
#
# m##################] | reify:yargs: timing reifyNode:node_modules/axios Complet 153ms
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.19.2.2:8502
#   External URL: http://34.28.59.197:8502
#
# your url is: https://legal-planes-wash.loca.lt
# New filename for the audio: audio
# The file does not exist
# ...
